# %%
from pymongo import MongoClient
import pandas

# %%
mongo_client = MongoClient('34.215.106.7', 27016)
database_reference = mongo_client.twitter
collection_reference = database_reference.tweets

# %%
cursor = collection_reference.find()

# %%
cursor.count()
# Out:
# 2148879

# %%
cursor.rewind()
cursor_sampl = collection_reference.aggregate([{'$sample': {'size': 400}}])

# %%
len(list(cursor_sampl))
# Out:
# 400

# %% [markdown]
# ![](https://i.imgflip.com/245tp9.jpg)

# %%
cursor_sampl

# %%
tweets = {}
cursor.rewind()
for i in range(0,399):
    tweets[i] = next(cursor)
next
tweets[0]
# Out:
# {'_id': ObjectId('5a4d5678bfe2f9001587a12e'),
#  'contributors': None,
#  'coordinates': None,
#  'created_at': 'Wed Jan 03 22:16:02 +0000 2018',
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': 0,
#  'favorited': False,
#  'filter_level': 'low',
#  'geo': None,
#  'id': 948679371505655808,
#  'id_str': '948679371505655808',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'tl',
#  'place': {'attributes': {},
#   'bounding_box': {'coordinates': [[[-118.668404, 33.704538],
#      [-118.668404, 34.337041],
#      [-118.155409, 34.337041],
#      [-118.155409, 33.704538]]],
#    'type': 'Polygon'},
#   'country': 'United States',
#   'country_code': 'US',
#   'full_name': 'Los Angeles, CA',
#   'id': '3b77caf94bfc81fe',
#   'name': 'Los Angeles',
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-f25961a80989> in <module>()
# ----> 1 head(tweets)
#
# NameError: name 'head' is not defined

# %%
pandas.DataFrame(tweets)
# Out:
#                                                                          0    \
# _id                                                 5a4d5678bfe2f9001587a12e
# contributors                                                            None
# coordinates                                                             None
# created_at                                    Wed Jan 03 22:16:02 +0000 2018
# display_text_range                                                       NaN
# entities                   {'hashtags': [], 'urls': [], 'user_mentions': ...
# extended_entities                                                        NaN
# extended_tweet                                                           NaN
# favorite_count                                                             0
# favorited                                                              False
# filter_level                                                             low
# ...

# %%
import numpy as np
tweet1 = tweets[0]

# %%
tweets[2]
# Out:
# {'_id': ObjectId('5a4d56d9bfe2f9001587a130'),
#  'contributors': None,
#  'coordinates': {'coordinates': [-118.44241261, 34.04491223], 'type': 'Point'},
#  'created_at': 'Wed Jan 03 22:16:04 +0000 2018',
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'urls': [{'display_url': 'instagram.com/p/BdgPSa5hQrc/',
#     'expanded_url': 'https://www.instagram.com/p/BdgPSa5hQrc/',
#     'indices': [96, 119],
#     'url': 'https://t.co/9kQpNWp4F9'}],
#   'user_mentions': []},
#  'favorite_count': 0,
#  'favorited': False,
#  'filter_level': 'low',
#  'geo': {'coordinates': [34.04491223, -118.44241261], 'type': 'Point'},
#  'id': 948679379957223427,
#  'id_str': '948679379957223427',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': {'attributes': {},
# ...

# %%
tweet1['user']['screen_name']
# Out:
# 'euanbedural_'

# %%
tweets[1]['user']['screen_name']
# Out:
# '_ohhbelen'

# %%
time = []
location = []
favorites = []
language = []
name = []
text = []

# %%
for i in range(0,398):
    time.append(tweets[i]['created_at'])
    favorites.append(tweets[i]['favorite_count'])
    language.append(tweets[i]['lang'])
    name.append(tweets[i]['user']['screen_name'])
    text.append(tweets[i]['text'])
    if tweets[i]['coordinates'] == tweets[0]['coordinates']:
        location.append("None")
    else:
        location.append(tweets[i]['coordinates']['coordinates'])
next
# Out:
# <function next>

# %%
location
# Out:
# ['None',
#  'None',
#  [-118.44241261, 34.04491223],
#  'None',
#  'None',
#  [-118.41485696, 33.40306001],
#  'None',
#  [-118.3006, 34.0618],
#  'None',
#  'None',
#  [-118.243, 34.0522],
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  [-118.36871887, 34.28341887],
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  [-118.4146057, 34.1574851],
#  'None',
#  'None',
#  'None',
#  [-118.773, 36.5642],
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  [-118.256404, 34.037168],
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  [-122.1802812, 37.3813444],
#  'None',
#  'None',
#  [-118.37279, 34.07576],
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  [-122.36396313, 37.53089733],
#  'None',
#  'None',
#  [-118.4798679, 33.9941517],
# ...

# %%
for
