# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /opt/conda/lib/python3.6/site-packages

# %%
from pymongo import MongoClient

# %%
mongo_client = MongoClient('34.209.155.42', 27016)
database_reference = mongo_client.twitter
collection_reference = database_reference.tweets

# %%
collection_reference.count()
# Out:
# 1973510

# %%
cursor = collection_reference.find()

# %%
next(cursor)
# Out:
# {'_id': ObjectId('5a4d5678bfe2f9001587a12e'),
#  'contributors': None,
#  'coordinates': None,
#  'created_at': 'Wed Jan 03 22:16:02 +0000 2018',
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': 0,
#  'favorited': False,
#  'filter_level': 'low',
#  'geo': None,
#  'id': 948679371505655808,
#  'id_str': '948679371505655808',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'tl',
#  'place': {'attributes': {},
#   'bounding_box': {'coordinates': [[[-118.668404, 33.704538],
#      [-118.668404, 34.337041],
#      [-118.155409, 34.337041],
#      [-118.155409, 33.704538]]],
#    'type': 'Polygon'},
#   'country': 'United States',
#   'country_code': 'US',
#   'full_name': 'Los Angeles, CA',
#   'id': '3b77caf94bfc81fe',
#   'name': 'Los Angeles',
#   'place_type': 'city',
#   'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json'},
#  'quote_count': 0,
#  'reply_count': 0,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'text': 'Putangina ang boring na ng buhay ko dito jusko',
#  'timestamp_ms': '1515017762434',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Fri Mar 02 13:22:22 +0000 2012',
#   'default_profile': False,
#   'default_profile_image': False,
#   'description': None,
#   'favourites_count': 4830,
#   'follow_request_sent': None,
#   'followers_count': 773,
#   'following': None,
#   'friends_count': 100,
#   'geo_enabled': True,
#   'id': 511923569,
#   'id_str': '511923569',
#   'is_translator': False,
#   'lang': 'en',
#   'listed_count': 1,
#   'location': 'Los Angeles, CA',
#   'name': 'Juan Miguel',
#   'notifications': None,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/531342961343086592/4a7yCk4x.jpeg',
#   'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/531342961343086592/4a7yCk4x.jpeg',
#   'profile_background_tile': False,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/511923569/1514535792',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/946844999412473856/07sICdIq_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/946844999412473856/07sICdIq_normal.jpg',
#   'profile_link_color': '000000',
#   'profile_sidebar_border_color': 'FFFFFF',
#   'profile_sidebar_fill_color': 'EFEFEF',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'euanbedural_',
#   'statuses_count': 5142,
#   'time_zone': 'Hong Kong',
#   'translator_type': 'none',
#   'url': None,
#   'utc_offset': 28800,
#   'verified': False}}

# %%
next(cursor)
# Out:
# {'_id': ObjectId('5a4d56d9bfe2f9001587a12f'),
#  'contributors': None,
#  'coordinates': None,
#  'created_at': 'Wed Jan 03 22:16:04 +0000 2018',
#  'display_text_range': [14, 25],
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'urls': [],
#   'user_mentions': [{'id': 828346564062044160,
#     'id_str': '828346564062044160',
#     'indices': [0, 13],
#     'name': 'alicia 🐻',
#     'screen_name': 'aliciabearrr'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'filter_level': 'low',
#  'geo': None,
#  'id': 948679379248283648,
#  'id_str': '948679379248283648',
#  'in_reply_to_screen_name': 'aliciabearrr',
#  'in_reply_to_status_id': 948634097961676800,
#  'in_reply_to_status_id_str': '948634097961676800',
#  'in_reply_to_user_id': 828346564062044160,
#  'in_reply_to_user_id_str': '828346564062044160',
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': {'attributes': {},
#   'bounding_box': {'coordinates': [[[-124.482003, 32.528832],
#      [-124.482003, 42.009519],
#      [-114.131212, 42.009519],
#      [-114.131212, 32.528832]]],
#    'type': 'Polygon'},
#   'country': 'United States',
#   'country_code': 'US',
#   'full_name': 'California, USA',
#   'id': 'fbd6d2f5a4e4a15e',
#   'name': 'California',
#   'place_type': 'admin',
#   'url': 'https://api.twitter.com/1.1/geo/id/fbd6d2f5a4e4a15e.json'},
#  'quote_count': 0,
#  'reply_count': 0,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'text': '@aliciabearrr Thank you 😋',
#  'timestamp_ms': '1515017764280',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Wed Sep 30 22:49:56 +0000 2015',
#   'default_profile': True,
#   'default_profile_image': False,
#   'description': 'momma to Leah 👩\u200d👧wife to Fernando 💍',
#   'favourites_count': 2115,
#   'follow_request_sent': None,
#   'followers_count': 308,
#   'following': None,
#   'friends_count': 250,
#   'geo_enabled': True,
#   'id': 3741582613,
#   'id_str': '3741582613',
#   'is_translator': False,
#   'lang': 'en',
#   'listed_count': 0,
#   'location': 'California',
#   'name': 'Maria Belen Serna',
#   'notifications': None,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3741582613/1514716470',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/947415653035646977/bH3yLoc2_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/947415653035646977/bH3yLoc2_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': '_ohhbelen',
#   'statuses_count': 8926,
#   'time_zone': None,
#   'translator_type': 'none',
#   'url': None,
#   'utc_offset': None,
#   'verified': False}}

# %%
next(cursor)['text']
# Out:
# 'It’s okay to invest in YOUrself. \nI beat myself up whenever i don’t cross out everything on my… https://t.co/9kQpNWp4F9'

# %%
type(next(cursor))
# Out:
# dict

# %%
next(cursor)['text']
# Out:
# 'Reading “Rest In Power” by Trayvon Martins parents.....can’t stop tearing up imagining what it would be like to go… https://t.co/PX1VJnJv4H'

# %%
print( next(cursor)['text'],
next(cursor)['text'],
next(cursor)['text'],
next(cursor)['text'],
next(cursor)['text'])
# Out:
# What a joke... Please draft his successor. https://t.co/fJTXbC0uAP @666shan All you really have is right now . Even as a Sixers fan, I think #DonovanMitchell is gaining steam on ROY award. And might win it. Ben doesn't have th… https://t.co/WrSyJ4EdY3 Nice job boys! #gainz https://t.co/V6BI4oclXd Breakfast food can serve many purposes

# %%
print( next(cursor)['created_at'],
next(cursor)['geo'],
next(cursor)['geo'],
next(cursor)['geo'],
next(cursor)['geo'])
# Out:
# Wed Jan 03 22:17:52 +0000 2018 {'type': 'Point', 'coordinates': [39.1969804, -120.2357055]} {'type': 'Point', 'coordinates': [35.19370363, -116.13391199]} None None

# %%
import pandas
import numpy

# %%
time = []
coordinates = []
favorites = []
language = []
name = []
text = []
tweets = []

# %%
cursor.rewind()
for i in range(0, 10):
    tweets.append(next(cursor))
next

tweets
# Out:
# [{'_id': ObjectId('5a4d5678bfe2f9001587a12e'),
#   'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Jan 03 22:16:02 +0000 2018',
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'filter_level': 'low',
#   'geo': None,
#   'id': 948679371505655808,
#   'id_str': '948679371505655808',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'tl',
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-118.668404, 33.704538],
#       [-118.668404, 34.337041],
#       [-118.155409, 34.337041],
#       [-118.155409, 33.704538]]],
#     'type': 'Polygon'},
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Los Angeles, CA',
#    'id': '3b77caf94bfc81fe',
#    'name': 'Los Angeles',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json'},
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'Putangina ang boring na ng buhay ko dito jusko',
#   'timestamp_ms': '1515017762434',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Mar 02 13:22:22 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': None,
#    'favourites_count': 4830,
#    'follow_request_sent': None,
#    'followers_count': 773,
#    'following': None,
#    'friends_count': 100,
#    'geo_enabled': True,
#    'id': 511923569,
#    'id_str': '511923569',
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 1,
#    'location': 'Los Angeles, CA',
#    'name': 'Juan Miguel',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/531342961343086592/4a7yCk4x.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/531342961343086592/4a7yCk4x.jpeg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/511923569/1514535792',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/946844999412473856/07sICdIq_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/946844999412473856/07sICdIq_normal.jpg',
#    'profile_link_color': '000000',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'euanbedural_',
#    'statuses_count': 5142,
#    'time_zone': 'Hong Kong',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': 28800,
#    'verified': False}},
#  {'_id': ObjectId('5a4d56d9bfe2f9001587a12f'),
#   'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Jan 03 22:16:04 +0000 2018',
#   'display_text_range': [14, 25],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 828346564062044160,
#      'id_str': '828346564062044160',
#      'indices': [0, 13],
#      'name': 'alicia 🐻',
#      'screen_name': 'aliciabearrr'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'filter_level': 'low',
#   'geo': None,
#   'id': 948679379248283648,
#   'id_str': '948679379248283648',
#   'in_reply_to_screen_name': 'aliciabearrr',
#   'in_reply_to_status_id': 948634097961676800,
#   'in_reply_to_status_id_str': '948634097961676800',
#   'in_reply_to_user_id': 828346564062044160,
#   'in_reply_to_user_id_str': '828346564062044160',
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-124.482003, 32.528832],
#       [-124.482003, 42.009519],
#       [-114.131212, 42.009519],
#       [-114.131212, 32.528832]]],
#     'type': 'Polygon'},
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'California, USA',
#    'id': 'fbd6d2f5a4e4a15e',
#    'name': 'California',
#    'place_type': 'admin',
#    'url': 'https://api.twitter.com/1.1/geo/id/fbd6d2f5a4e4a15e.json'},
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': '@aliciabearrr Thank you 😋',
#   'timestamp_ms': '1515017764280',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Sep 30 22:49:56 +0000 2015',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'momma to Leah 👩\u200d👧wife to Fernando 💍',
#    'favourites_count': 2115,
#    'follow_request_sent': None,
#    'followers_count': 308,
#    'following': None,
#    'friends_count': 250,
#    'geo_enabled': True,
#    'id': 3741582613,
#    'id_str': '3741582613',
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'California',
#    'name': 'Maria Belen Serna',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3741582613/1514716470',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/947415653035646977/bH3yLoc2_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/947415653035646977/bH3yLoc2_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': '_ohhbelen',
#    'statuses_count': 8926,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'_id': ObjectId('5a4d56d9bfe2f9001587a130'),
#   'contributors': None,
#   'coordinates': {'coordinates': [-118.44241261, 34.04491223],
#    'type': 'Point'},
#   'created_at': 'Wed Jan 03 22:16:04 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'instagram.com/p/BdgPSa5hQrc/',
#      'expanded_url': 'https://www.instagram.com/p/BdgPSa5hQrc/',
#      'indices': [96, 119],
#      'url': 'https://t.co/9kQpNWp4F9'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'filter_level': 'low',
#   'geo': {'coordinates': [34.04491223, -118.44241261], 'type': 'Point'},
#   'id': 948679379957223427,
#   'id_str': '948679379957223427',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-118.668404, 33.704538],
#       [-118.668404, 34.337041],
#       [-118.155409, 34.337041],
#       [-118.155409, 33.704538]]],
#     'type': 'Polygon'},
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Los Angeles, CA',
#    'id': '3b77caf94bfc81fe',
#    'name': 'Los Angeles',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json'},
#   'possibly_sensitive': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://instagram.com" rel="nofollow">Instagram</a>',
#   'text': 'It’s okay to invest in YOUrself. \nI beat myself up whenever i don’t cross out everything on my… https://t.co/9kQpNWp4F9',
#   'timestamp_ms': '1515017764449',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Jul 31 22:28:02 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'LA🌴 I turned bad habits into good habits. Health Coach | karaoke queen | noceur ✨',
#    'favourites_count': 574,
#    'follow_request_sent': None,
#    'followers_count': 337,
#    'following': None,
#    'friends_count': 239,
#    'geo_enabled': True,
#    'id': 61891630,
#    'id_str': '61891630',
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 10,
#    'location': 'NORTH HOLLYWOOD',
#    'name': 'IG: Lorenamour64',
#    'notifications': None,
#    'profile_background_color': '050108',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/812409981/afaa27bf78e5a0e0f394e29f6ca71e2c.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/812409981/afaa27bf78e5a0e0f394e29f6ca71e2c.jpeg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/61891630/1423650146',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/921581872206954496/QksJ_AK__normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/921581872206954496/QksJ_AK__normal.jpg',
#    'profile_link_color': 'FF0000',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'E3E2DE',
#    'profile_text_color': '634047',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Lorena64o',
#    'statuses_count': 3164,
#    'time_zone': 'Pacific Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://www.goherbalife.com/lramirez2/en-US',
#    'utc_offset': -28800,
#    'verified': False}},
#  {'_id': ObjectId('5a4d56d9bfe2f9001587a131'),
#   'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Jan 03 22:16:05 +0000 2018',
#   'display_text_range': [0, 60],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/dammitarsenal/…',
#      'expanded_url': 'https://twitter.com/dammitarsenal/status/948653084711952384',
#      'indices': [61, 84],
#      'url': 'https://t.co/WlV6jFpGnn'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'filter_level': 'low',
#   'geo': None,
#   'id': 948679384180797440,
#   'id_str': '948679384180797440',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': True,
#   'lang': 'en',
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-118.668404, 33.704538],
#       [-118.668404, 34.337041],
#       [-118.155409, 34.337041],
#       [-118.155409, 33.704538]]],
#     'type': 'Polygon'},
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Los Angeles, CA',
#    'id': '3b77caf94bfc81fe',
#    'name': 'Los Angeles',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json'},
#   'possibly_sensitive': False,
#   'quote_count': 0,
#   'quoted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Jan 03 20:31:35 +0000 2018',
#    'display_text_range': [0, 55],
#    'entities': {'hashtags': [],
#     'media': [{'display_url': 'pic.twitter.com/HyBBOlB8xU',
#       'expanded_url': 'https://twitter.com/DammitArsenal/status/948653084711952384/video/1',
#       'id': 948652884811440128,
#       'id_str': '948652884811440128',
#       'indices': [56, 79],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/948652884811440128/pu/img/2Isy8zymDVaHBltE.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/948652884811440128/pu/img/2Isy8zymDVaHBltE.jpg',
#       'sizes': {'large': {'h': 720, 'resize': 'fit', 'w': 1280},
#        'medium': {'h': 675, 'resize': 'fit', 'w': 1200},
#        'small': {'h': 383, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/HyBBOlB8xU'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/HyBBOlB8xU',
#       'expanded_url': 'https://twitter.com/DammitArsenal/status/948653084711952384/video/1',
#       'id': 948652884811440128,
#       'id_str': '948652884811440128',
#       'indices': [56, 79],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/948652884811440128/pu/img/2Isy8zymDVaHBltE.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/948652884811440128/pu/img/2Isy8zymDVaHBltE.jpg',
#       'sizes': {'large': {'h': 720, 'resize': 'fit', 'w': 1280},
#        'medium': {'h': 675, 'resize': 'fit', 'w': 1200},
#        'small': {'h': 383, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'video',
#       'url': 'https://t.co/HyBBOlB8xU',
#       'video_info': {'aspect_ratio': [16, 9],
#        'duration_millis': 11398,
#        'variants': [{'bitrate': 832000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/948652884811440128/pu/vid/640x360/2EdhmXSJ3mdoQ67P.mp4'},
#         {'bitrate': 2176000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/948652884811440128/pu/vid/1280x720/d8Yy5B7krXSgzwyK.mp4'},
#         {'content_type': 'application/x-mpegURL',
#          'url': 'https://video.twimg.com/ext_tw_video/948652884811440128/pu/pl/QpFFPYH3aB5Ppnkj.m3u8'},
#         {'bitrate': 320000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/948652884811440128/pu/vid/320x180/2ffL_u2qjJ4AOR83.mp4'}]}}]},
#    'favorite_count': 388,
#    'favorited': False,
#    'filter_level': 'low',
#    'geo': None,
#    'id': 948653084711952384,
#    'id_str': '948653084711952384',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'place': None,
#    'possibly_sensitive': False,
#    'quote_count': 39,
#    'reply_count': 9,
#    'retweet_count': 222,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': "Wenger writes down...Fabregas's hug calms Sanchez down. https://t.co/HyBBOlB8xU",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed May 03 12:31:32 +0000 2017',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Tweets are mostly related to Arsenal and European football. #afc --- @ArsenalPoper taken away at 19k : /',
#     'favourites_count': 554,
#     'follow_request_sent': None,
#     'followers_count': 7393,
#     'following': None,
#     'friends_count': 4452,
#     'geo_enabled': False,
#     'id': 859747248783142914,
#     'id_str': '859747248783142914',
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 22,
#     'location': None,
#     'name': 'Arsenal',
#     'notifications': None,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': '',
#     'profile_background_image_url_https': '',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/859747248783142914/1513075327',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/946496025480400896/mxtwN2X5_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/946496025480400896/mxtwN2X5_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'DammitArsenal',
#     'statuses_count': 593,
#     'time_zone': 'Pacific Time (US & Canada)',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': -28800,
#     'verified': False}},
#   'quoted_status_id': 948653084711952384,
#   'quoted_status_id_str': '948653084711952384',
#   'reply_count': 0,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'Best sportsmanship I’ve seen in years. Alexis to Chelsea? 👀👀 https://t.co/WlV6jFpGnn',
#   'timestamp_ms': '1515017765456',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Jun 05 04:16:02 +0000 2010',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': "I've been an asshole before it was fashionable.",
#    'favourites_count': 3548,
#    'follow_request_sent': None,
#    'followers_count': 259,
#    'following': None,
#    'friends_count': 74,
#    'geo_enabled': True,
#    'id': 152126960,
#    'id_str': '152126960',
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 1,
#    'location': 'Hollywood, Los Angeles',
#    'name': 'Fucci Mane',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme6/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme6/bg.gif',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/152126960/1508896152',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/902746989598695424/3Fb781FO_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/902746989598695424/3Fb781FO_normal.jpg',
#    'profile_link_color': 'E81C4F',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'Manny_McFlyy',
#    'statuses_count': 19895,
#    'time_zone': 'Pacific Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -28800,
#    'verified': False}},
#  {'_id': ObjectId('5a4d56d9bfe2f9001587a132'),
#   'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Jan 03 22:16:07 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#      'expanded_url': 'https://twitter.com/i/web/status/948679393865490432',
#      'indices': [116, 139],
#      'url': 'https://t.co/PX1VJnJv4H'}],
#    'user_mentions': []},
#   'extended_tweet': {'display_text_range': [0, 143],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'full_text': 'Reading “Rest In Power” by Trayvon Martins parents.....can’t stop tearing up imagining what it would be like to go through this as a parent smh'},
#   'favorite_count': 0,
#   'favorited': False,
#   'filter_level': 'low',
#   'geo': None,
#   'id': 948679393865490432,
#   'id_str': '948679393865490432',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-118.668404, 33.704538],
#       [-118.668404, 34.337041],
#       [-118.155409, 34.337041],
#       [-118.155409, 33.704538]]],
#     'type': 'Polygon'},
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Los Angeles, CA',
#    'id': '3b77caf94bfc81fe',
#    'name': 'Los Angeles',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json'},
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'Reading “Rest In Power” by Trayvon Martins parents.....can’t stop tearing up imagining what it would be like to go… https://t.co/PX1VJnJv4H',
#   'timestamp_ms': '1515017767765',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Jul 30 05:07:03 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'sweet oblivion. I pick up the pen as an anti depressant.',
#    'favourites_count': 10731,
#    'follow_request_sent': None,
#    'followers_count': 907,
#    'following': None,
#    'friends_count': 619,
#    'geo_enabled': True,
#    'id': 345175511,
#    'id_str': '345175511',
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 9,
#    'location': 'nowhere.',
#    'name': 'C Banga✨',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000021009686/688688f2fec583479d396feccbae0698.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000021009686/688688f2fec583479d396feccbae0698.jpeg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/345175511/1512423558',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/948241822026891266/NUi1axyn_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/948241822026891266/NUi1axyn_normal.jpg',
#    'profile_link_color': 'F5ABB5',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': '1A1A1A',
#    'profile_text_color': 'B36FB3',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Crystaaalina',
#    'statuses_count': 59823,
#    'time_zone': 'Pacific Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://Instagram.com/crystaaalina',
#    'utc_offset': -28800,
#    'verified': False}},
#  {'_id': ObjectId('5a4d56d9bfe2f9001587a133'),
#   'contributors': None,
#   'coordinates': {'coordinates': [-118.41485696, 33.40306001],
#    'type': 'Point'},
#   'created_at': 'Wed Jan 03 22:16:10 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'instagram.com/p/BdgPThHF4vhZ…',
#      'expanded_url': 'https://www.instagram.com/p/BdgPThHF4vhZMWgkdtqiI8ttmDUJa0zvBSU1NY0/',
#      'indices': [39, 62],
#      'url': 'https://t.co/hJHmNaySpw'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'filter_level': 'low',
#   'geo': {'coordinates': [33.40306001, -118.41485696], 'type': 'Point'},
#   'id': 948679403621507072,
#   'id_str': '948679403621507072',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-124.482003, 32.528832],
#       [-124.482003, 42.009519],
#       [-114.131212, 42.009519],
#       [-114.131212, 32.528832]]],
#     'type': 'Polygon'},
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'California, USA',
#    'id': 'fbd6d2f5a4e4a15e',
#    'name': 'California',
#    'place_type': 'admin',
#    'url': 'https://api.twitter.com/1.1/geo/id/fbd6d2f5a4e4a15e.json'},
#   'possibly_sensitive': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://instagram.com" rel="nofollow">Instagram</a>',
#   'text': 'Pit stop! c_caab4 @ Airport in the Sky https://t.co/hJHmNaySpw',
#   'timestamp_ms': '1515017770091',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Aug 19 10:34:24 +0000 2010',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Producer for the K-Earth 101 Morning Show with Gary Bryan. Home of the Greatest Hits On Earth, K-Earth 101!',
#    'favourites_count': 4930,
#    'follow_request_sent': None,
#    'followers_count': 1212,
#    'following': None,
#    'friends_count': 2382,
#    'geo_enabled': True,
#    'id': 180325580,
#    'id_str': '180325580',
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 23,
#    'location': 'Los Angeles, CA',
#    'name': 'Brandon J. Castillo',
#    'notifications': None,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/234770470/Brandon_KEARTH_Mic_Cropped.JPG',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/234770470/Brandon_KEARTH_Mic_Cropped.JPG',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/180325580/1407465173',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2653509624/8515c17e62ea3dbf31eaabc51ad214fd_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2653509624/8515c17e62ea3dbf31eaabc51ad214fd_normal.jpeg',
#    'profile_link_color': 'FF691F',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'BrandonKEARTH',
#    'statuses_count': 7012,
#    'time_zone': 'Pacific Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://www.kearth101.com',
#    'utc_offset': -28800,
#    'verified': False}},
#  {'_id': ObjectId('5a4d56d9bfe2f9001587a134'),
#   'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Jan 03 22:16:10 +0000 2018',
#   'display_text_range': [0, 88],
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/J0W7RWimng',
#      'expanded_url': 'https://twitter.com/JohnBonanno1/status/948679406632943617/photo/1',
#      'id': 948679395215998976,
#      'id_str': '948679395215998976',
#      'indices': [89, 112],
#      'media_url': 'http://pbs.twimg.com/media/DSpi4jWVAAAPbrH.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DSpi4jWVAAAPbrH.jpg',
#      'sizes': {'large': {'h': 1600, 'resize': 'fit', 'w': 1600},
#       'medium': {'h': 1200, 'resize': 'fit', 'w': 1200},
#       'small': {'h': 680, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/J0W7RWimng'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': []},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/J0W7RWimng',
#      'expanded_url': 'https://twitter.com/JohnBonanno1/status/948679406632943617/photo/1',
#      'id': 948679395215998976,
#      'id_str': '948679395215998976',
#      'indices': [89, 112],
#      'media_url': 'http://pbs.twimg.com/media/DSpi4jWVAAAPbrH.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DSpi4jWVAAAPbrH.jpg',
#      'sizes': {'large': {'h': 1600, 'resize': 'fit', 'w': 1600},
#       'medium': {'h': 1200, 'resize': 'fit', 'w': 1200},
#       'small': {'h': 680, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/J0W7RWimng'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'filter_level': 'low',
#   'geo': None,
#   'id': 948679406632943617,
#   'id_str': '948679406632943617',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-118.668404, 33.704538],
#       [-118.668404, 34.337041],
#       [-118.155409, 34.337041],
#       [-118.155409, 33.704538]]],
#     'type': 'Polygon'},
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Los Angeles, CA',
#    'id': '3b77caf94bfc81fe',
#    'name': 'Los Angeles',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json'},
#   'possibly_sensitive': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'Mueller get trumps taxes  you will see money laundering ,trump your ego drought you down https://t.co/J0W7RWimng',
#   'timestamp_ms': '1515017770809',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Sep 14 21:03:09 +0000 2015',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'I paint pictures I have over 500 paintings they are all signed an I have the next picasso. looking for investor contact me. Johnnybonnano@gmail.com',
#    'favourites_count': 70,
#    'follow_request_sent': None,
#    'followers_count': 7,
#    'following': None,
#    'friends_count': 98,
#    'geo_enabled': True,
#    'id': 3656825957,
#    'id_str': '3656825957',
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 1,
#    'location': 'johnnybonnano@gmail.com ',
#    'name': 'John Bonanno . johnn',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3656825957/1469244729',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/756693358454706176/hSGRjR-g_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/756693358454706176/hSGRjR-g_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'JohnBonanno1',
#    'statuses_count': 616,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'_id': ObjectId('5a4d56d9bfe2f9001587a135'),
#   'contributors': None,
#   'coordinates': {'coordinates': [-118.3006, 34.0618], 'type': 'Point'},
#   'created_at': 'Wed Jan 03 22:16:11 +0000 2018',
#   'entities': {'hashtags': [{'indices': [10, 24], 'text': 'relationships'},
#     {'indices': [25, 30], 'text': 'love'},
#     {'indices': [31, 43], 'text': 'lifeincolor'},
#     {'indices': [44, 51], 'text': 'quirky'}],
#    'symbols': [],
#    'urls': [{'display_url': 'instagram.com/p/BdgPTVkBucL/',
#      'expanded_url': 'https://www.instagram.com/p/BdgPTVkBucL/',
#      'indices': [77, 100],
#      'url': 'https://t.co/gyIjqCRsOT'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'filter_level': 'low',
#   'geo': {'coordinates': [34.0618, -118.3006], 'type': 'Point'},
#   'id': 948679410915381249,
#   'id_str': '948679410915381249',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-118.668404, 33.704538],
#       [-118.668404, 34.337041],
#       [-118.155409, 34.337041],
#       [-118.155409, 33.704538]]],
#     'type': 'Polygon'},
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Los Angeles, CA',
#    'id': '3b77caf94bfc81fe',
#    'name': 'Los Angeles',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json'},
#   'possibly_sensitive': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://instagram.com" rel="nofollow">Instagram</a>',
#   'text': 'Always! 😘 #relationships #love #lifeincolor #quirky @ Koreatown, Los Angeles https://t.co/gyIjqCRsOT',
#   'timestamp_ms': '1515017771830',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Nov 20 03:38:48 +0000 2008',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '#actress 🎭 #producer 🎬 #model ➕\n#nerdylatina 🤓🇵🇷  #animallover 🐱🐶🐰#mentalhealthadvocate ❤',
#    'favourites_count': 4273,
#    'follow_request_sent': None,
#    'followers_count': 2874,
#    'following': None,
#    'friends_count': 4451,
#    'geo_enabled': True,
#    'id': 17503638,
#    'id_str': '17503638',
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 93,
#    'location': 'Los Angeles, CA',
#    'name': 'Massiel Hernandez',
#    'notifications': None,
#    'profile_background_color': '91BDB6',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/553227875/BLACKBIRDS.jpg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/553227875/BLACKBIRDS.jpg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/17503638/1481173226',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/882824518426923008/qCk2UC5K_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/882824518426923008/qCk2UC5K_normal.jpg',
#    'profile_link_color': '038543',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'F6F6F6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'MassielNH',
#    'statuses_count': 18419,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://www.patreon.com/massielnh',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'_id': ObjectId('5a4d56d9bfe2f9001587a136'),
#   'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Jan 03 22:16:13 +0000 2018',
#   'display_text_range': [12, 62],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 607563605,
#      'id_str': '607563605',
#      'indices': [0, 11],
#      'name': 'K. Scott',
#      'screen_name': 'Oh_K_Scott'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'filter_level': 'low',
#   'geo': None,
#   'id': 948679419303874560,
#   'id_str': '948679419303874560',
#   'in_reply_to_screen_name': 'Oh_K_Scott',
#   'in_reply_to_status_id': 948679200986218497,
#   'in_reply_to_status_id_str': '948679200986218497',
#   'in_reply_to_user_id': 607563605,
#   'in_reply_to_user_id_str': '607563605',
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-118.668404, 33.704538],
#       [-118.668404, 34.337041],
#       [-118.155409, 34.337041],
#       [-118.155409, 33.704538]]],
#     'type': 'Polygon'},
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Los Angeles, CA',
#    'id': '3b77caf94bfc81fe',
#    'name': 'Los Angeles',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json'},
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': '@Oh_K_Scott I use all forms of communication minus actual mail',
#   'timestamp_ms': '1515017773830',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Oct 24 18:29:18 +0000 2010',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'I sell dildos for a living, if what I say offends you, I’m doing my job....1000% MINE, all MINE',
#    'favourites_count': 54688,
#    'follow_request_sent': None,
#    'followers_count': 990,
#    'following': None,
#    'friends_count': 1513,
#    'geo_enabled': True,
#    'id': 207179489,
#    'id_str': '207179489',
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 9,
#    'location': 'Los Angeles, CA',
#    'name': '⬛️Darth Geesus◼️',
#    'notifications': None,
#    'profile_background_color': '1A1B1F',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/449789188/IMG_0861.PNG',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/449789188/IMG_0861.PNG',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/207179489/1511311389',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/933133710555201536/yrGcPJMA_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/933133710555201536/yrGcPJMA_normal.jpg',
#    'profile_link_color': '0CCC39',
#    'profile_sidebar_border_color': '181A1E',
#    'profile_sidebar_fill_color': '252429',
#    'profile_text_color': '0DE026',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'StevieGeesus',
#    'statuses_count': 12731,
#    'time_zone': 'Pacific Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -28800,
#    'verified': False}},
#  {'_id': ObjectId('5a4d56dabfe2f9001587a137'),
#   'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Jan 03 22:16:14 +0000 2018',
#   'display_text_range': [0, 39],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/shiwantsthec/s…',
#      'expanded_url': 'https://twitter.com/shiwantsthec/status/948393423907811329',
#      'indices': [40, 63],
#      'url': 'https://t.co/9AgYwt6lRq'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'filter_level': 'low',
#   'geo': None,
#   'id': 948679422093111296,
#   'id_str': '948679422093111296',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': True,
#   'lang': 'en',
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-118.668404, 33.704538],
#       [-118.668404, 34.337041],
#       [-118.155409, 34.337041],
#       [-118.155409, 33.704538]]],
#     'type': 'Polygon'},
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Los Angeles, CA',
#    'id': '3b77caf94bfc81fe',
#    'name': 'Los Angeles',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json'},
#   'possibly_sensitive': False,
#   'quote_count': 0,
#   'quoted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Jan 03 03:19:47 +0000 2018',
#    'display_text_range': [0, 48],
#    'entities': {'hashtags': [],
#     'media': [{'display_url': 'pic.twitter.com/IWjCqxfUXE',
#       'expanded_url': 'https://twitter.com/ShiWantsTheC/status/948393423907811329/photo/1',
#       'id': 948393277295865857,
#       'id_str': '948393277295865857',
#       'indices': [49, 72],
#       'media_url': 'http://pbs.twimg.com/media/DSleqTCWsAE-oyx.png',
#       'media_url_https': 'https://pbs.twimg.com/media/DSleqTCWsAE-oyx.png',
#       'sizes': {'large': {'h': 792, 'resize': 'fit', 'w': 613},
#        'medium': {'h': 792, 'resize': 'fit', 'w': 613},
#        'small': {'h': 680, 'resize': 'fit', 'w': 526},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/IWjCqxfUXE'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/IWjCqxfUXE',
#       'expanded_url': 'https://twitter.com/ShiWantsTheC/status/948393423907811329/photo/1',
#       'id': 948393277295865857,
#       'id_str': '948393277295865857',
#       'indices': [49, 72],
#       'media_url': 'http://pbs.twimg.com/media/DSleqTCWsAE-oyx.png',
#       'media_url_https': 'https://pbs.twimg.com/media/DSleqTCWsAE-oyx.png',
#       'sizes': {'large': {'h': 792, 'resize': 'fit', 'w': 613},
#        'medium': {'h': 792, 'resize': 'fit', 'w': 613},
#        'small': {'h': 680, 'resize': 'fit', 'w': 526},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/IWjCqxfUXE'}]},
#    'favorite_count': 1527,
#    'favorited': False,
#    'filter_level': 'low',
#    'geo': None,
#    'id': 948393423907811329,
#    'id_str': '948393423907811329',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'place': None,
#    'possibly_sensitive': True,
#    'quote_count': 286,
#    'reply_count': 46,
#    'retweet_count': 1117,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': "OMG THIS YEAR'S COACHELLA LINEUP LOOKS SICK AF!! https://t.co/IWjCqxfUXE",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sat Apr 26 17:11:37 +0000 2014',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': "i'm the guy that Paquita La Del Barrio insults on all of her songs.. Dropping my new Corrido Mixtape Volume 2 on ya guys pretty soon. Follow for Hispanic Tweets",
#     'favourites_count': 33965,
#     'follow_request_sent': None,
#     'followers_count': 67446,
#     'following': None,
#     'friends_count': 36857,
#     'geo_enabled': True,
#     'id': 2464894184,
#     'id_str': '2464894184',
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 243,
#     'location': None,
#     'name': 'She Wants The Chorizo',
#     'notifications': None,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2464894184/1489858589',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/856892127091068928/UYDcNgNJ_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/856892127091068928/UYDcNgNJ_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'ShiWantsTheC',
#     'statuses_count': 35154,
#     'time_zone': 'Pacific Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'http://soundcloud.com/CorridoMixtapeRadio',
#     'utc_offset': -28800,
#     'verified': False}},
#   'quoted_status_id': 948393423907811329,
#   'quoted_status_id_str': '948393423907811329',
#   'reply_count': 0,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'Definitely getting my ticket for this 🤣 https://t.co/9AgYwt6lRq',
#   'timestamp_ms': '1515017774495',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Sep 20 20:34:44 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Ig: Cocaine_Papi_1',
#    'favourites_count': 5472,
#    'follow_request_sent': None,
#    'followers_count': 416,
#    'following': None,
#    'friends_count': 306,
#    'geo_enabled': True,
#    'id': 376983874,
#    'id_str': '376983874',
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 5,
#    'location': 'Los Angeles ⚽',
#    'name': 'Aaron Ruiz',
#    'notifications': None,
#    'profile_background_color': '2E021B',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000133592861/SxMzY6PN.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000133592861/SxMzY6PN.jpeg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/376983874/1459839815',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/665024649420341253/V3kOdMds_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/665024649420341253/V3kOdMds_normal.jpg',
#    'profile_link_color': '0098B3',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'C0DFEC',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'cocaine_papi_',
#    'statuses_count': 22547,
#    'time_zone': 'Arizona',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -25200,
#    'verified': False}}]

# %%
tweets2 = []
tweets1 = tweets[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-116-88a144139908> in <module>()
#       1 tweets2 = []
# ----> 2 tweets1 = tweets[1]
#
# IndexError: list index out of range

# %%
tweets['user']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-115-b3bc3f04ca0f> in <module>()
# ----> 1 tweets['user']
#
# TypeError: list indices must be integers or slices, not str

# %%
cursor.rewind()
for i in range(0, 10):
    time.append(next(cursor)['created_at'])
next

cursor.rewind()
for i in range(0, 10):
    name.append(next(cursor)['user'][i]['screen_name'])
next

cursor.rewind()
for i in range(0, 10):
    text.append(next(cursor)['text'])
next

time
name
text
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-108-6a11548bf622> in <module>()
#       6 cursor.rewind()
#       7 for i in range(0, 10):
# ----> 8     name.append(next(cursor)['user'][i]['screen_name'])
#       9 next
#      10
#
# KeyError: 0

# %%
cursor.rewind()

# %%
next(cursor)
# Out:
# {'_id': ObjectId('5a4d56d9bfe2f9001587a12f'),
#  'contributors': None,
#  'coordinates': None,
#  'created_at': 'Wed Jan 03 22:16:04 +0000 2018',
#  'display_text_range': [14, 25],
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'urls': [],
#   'user_mentions': [{'id': 828346564062044160,
#     'id_str': '828346564062044160',
#     'indices': [0, 13],
#     'name': 'alicia 🐻',
#     'screen_name': 'aliciabearrr'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'filter_level': 'low',
#  'geo': None,
#  'id': 948679379248283648,
#  'id_str': '948679379248283648',
#  'in_reply_to_screen_name': 'aliciabearrr',
#  'in_reply_to_status_id': 948634097961676800,
#  'in_reply_to_status_id_str': '948634097961676800',
#  'in_reply_to_user_id': 828346564062044160,
#  'in_reply_to_user_id_str': '828346564062044160',
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': {'attributes': {},
#   'bounding_box': {'coordinates': [[[-124.482003, 32.528832],
#      [-124.482003, 42.009519],
#      [-114.131212, 42.009519],
#      [-114.131212, 32.528832]]],
#    'type': 'Polygon'},
#   'country': 'United States',
#   'country_code': 'US',
#   'full_name': 'California, USA',
#   'id': 'fbd6d2f5a4e4a15e',
#   'name': 'California',
#   'place_type': 'admin',
#   'url': 'https://api.twitter.com/1.1/geo/id/fbd6d2f5a4e4a15e.json'},
#  'quote_count': 0,
#  'reply_count': 0,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'text': '@aliciabearrr Thank you 😋',
#  'timestamp_ms': '1515017764280',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Wed Sep 30 22:49:56 +0000 2015',
#   'default_profile': True,
#   'default_profile_image': False,
#   'description': 'momma to Leah 👩\u200d👧wife to Fernando 💍',
#   'favourites_count': 2115,
#   'follow_request_sent': None,
#   'followers_count': 308,
#   'following': None,
#   'friends_count': 250,
#   'geo_enabled': True,
#   'id': 3741582613,
#   'id_str': '3741582613',
#   'is_translator': False,
#   'lang': 'en',
#   'listed_count': 0,
#   'location': 'California',
#   'name': 'Maria Belen Serna',
#   'notifications': None,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3741582613/1514716470',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/947415653035646977/bH3yLoc2_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/947415653035646977/bH3yLoc2_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': '_ohhbelen',
#   'statuses_count': 8926,
#   'time_zone': None,
#   'translator_type': 'none',
#   'url': None,
#   'utc_offset': None,
#   'verified': False}}
